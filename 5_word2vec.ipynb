# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
    """Download a file if not present, and make sure it's the right size."""
    if not os.path.exists(filename):
        filename, _ = urlretrieve(url + filename, filename)
    statinfo = os.stat(filename)
    if statinfo.st_size == expected_bytes:
        print('Found and verified %s' % filename)
    else:
        print(statinfo.st_size)
        raise Exception(
              'Failed to verify ' + filename + '. Can you get to it with a browser?')
    return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
    """Extract the first file enclosed in a zip file as a list of words"""
    with zipfile.ZipFile(filename) as f:
        data = tf.compat.as_str(f.read(f.namelist()[0])).split()
    return data
  
words = read_data('./text8.zip')
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0  # dictionary['UNK']
        unk_count = unk_count + 1
        data.append(index)
    count[0][1] = unk_count
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
    return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 17005207], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %%
len(data), data[0], len(set(data))
# Out:
# (17005207, 5234, 50000)

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1 # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size // num_skips):
        target = skip_window  # target label at the center of the buffer
        targets_to_avoid = [ skip_window ]
        for j in range(num_skips):
            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
            targets_to_avoid.append(target)
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[target]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'a', 'originated', 'term', 'as', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['term', 'originated', 'anarchism', 'a', 'originated', 'term', 'as', 'of']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 2 # How many words to consider left and right.
num_skips = 4 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
    # Variables.
    embeddings = tf.Variable(
                    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(
                    tf.truncated_normal([vocabulary_size, embedding_size],
                                         stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
    # Model.
    # Look up embeddings for inputs.
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(
        tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` method will by default modify all variable quantities 
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)

    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(
                            normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(
                                  batch_size, num_skips, skip_window)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.535787
# Nearest to new: nike, signature, compiled, bailiwick, symphonies, jadwiga, auxerre, defining,
# Nearest to seven: futurama, undisturbed, adiabats, decoded, sticky, sicilian, eeeeee, dragoons,
# Nearest to was: righteous, myrddin, pose, retook, nit, galley, remote, demonolatry,
# Nearest to d: ingress, odrade, match, remarked, silverberg, reindeer, humidity, coon,
# Nearest to states: psychoanalyst, garbage, cyanides, fingerings, quiet, stated, supported, tasso,
# Nearest to by: hopelessly, skywalker, organism, lynching, redirected, stevie, wrestlemania, unicode,
# Nearest to at: arecibo, slippage, postalveolar, methionine, frying, snowboarding, ubangi, silvery,
# Nearest to an: anagram, bannockburn, possessed, berets, cumbric, northside, wissenschaften, adaptor,
# Nearest to than: hmso, saudi, web, being, pharisees, louisville, sclc, caledonians,
# Nearest to is: elections, boyhood, regolith, bodybuilding, bengali, centaurus, meath, biot,
# Nearest to would: radioisotope, picatinny, mpls, omen, khwarizmi, najd, uploaded, moving,
# Nearest to this: imran, packet, slashdot, geography, christensen, contractors, prosperity, how,
# Nearest to war: possibility, triads, investigators, aggressiveness, stoke, ica, menagerie, brother,
# Nearest to may: ajanta, condemned, guatemalan, reverend, nebulous, noll, hayes, linen,
# Nearest to often: miocene, swami, discrediting, mitotic, fushimi, matra, halted, aleinu,
# Nearest to were: implantation, chromatin, jutsu, unleash, impure, conflicts, landfill, interconnected,
# Average loss at step 2000: 4.493108
# Average loss at step 4000: 4.111559
# Average loss at step 6000: 3.970666
# Average loss at step 8000: 3.891946
# Average loss at step 10000: 3.926038
# Nearest to new: signature, beauchamp, forceful, nike, kc, limburgish, nowy, strewn,
# Nearest to seven: eight, four, six, five, three, nine, two, one,
# Nearest to was: is, be, normalized, had, unjust, serapis, negative, went,
# Nearest to d: cubans, bestows, beckham, quasi, beanstalk, snp, bombed, match,
# Nearest to states: psychoanalyst, contemporary, garbage, yuan, beloved, fingerings, stated, fees,
# Nearest to by: interruptions, merwara, anthology, who, UNK, certificates, vistula, leases,
# Nearest to at: with, thursdays, idiom, pronged, nitric, superior, kouchner, acker,
# Nearest to an: a, servicio, the, mirabilis, ayyubid, liquor, cath, going,
# Nearest to than: hmso, being, sclc, streaks, pharisees, upbeat, web, dictatorships,
# Nearest to is: was, has, are, be, qwerty, as, inherit, hoof,
# Nearest to would: picatinny, fluctuate, moving, adventures, japh, nightmare, radioisotope, najd,
# Nearest to this: it, that, condominiums, a, avalokitesvara, there, also, uart,
# Nearest to war: possibility, patrice, brother, triads, nejd, meltzer, hoses, aggressiveness,
# Nearest to may: nebulous, rainforest, can, popularized, hetzel, addressing, condemned, ajanta,
# Nearest to often: matra, also, chestnuts, cameroun, spooner, uttar, blenheim, sharpening,
# Nearest to were: are, kraft, have, had, impure, be, landfill, chromatin,
# Average loss at step 12000: 3.932663
# Average loss at step 14000: 3.852482
# Average loss at step 16000: 3.835898
# Average loss at step 18000: 3.728366
# Average loss at step 20000: 3.714636
# Nearest to new: publishing, nike, signature, beauchamp, gheg, strewn, scraping, opposites,
# Nearest to seven: eight, six, nine, four, three, five, one, zero,
# Nearest to was: is, were, has, had, been, be, petronas, being,
# Nearest to d: b, c, corrections, silverberg, cubans, lai, bestows, walter,
# Nearest to states: psychoanalyst, fingerings, nations, contemporary, legate, neodymium, collaborating, redneck,
# Nearest to by: bram, says, useless, merwara, discredit, through, has, stalling,
# Nearest to at: filename, idiom, males, phallic, arrays, comments, superior, meaningfully,
# Nearest to an: the, a, this, mirabilis, humps, noblemen, UNK, senseless,
# Nearest to than: hmso, upbeat, wrong, sufficiency, preservation, or, gein, pashtuns,
# Nearest to is: was, are, has, interchange, labarum, marathon, be, samos,
# Nearest to would: may, to, can, will, could, radioisotope, fluctuate, saying,
# Nearest to this: it, a, which, an, chose, the, weinberg, visitor,
# Nearest to war: aml, fowl, ica, possibility, ghost, menzies, padawan, nejd,
# Nearest to may: would, can, will, could, volleyball, rainforest, popularized, nebulous,
# Nearest to often: also, blenheim, matra, these, not, cameroun, chestnuts, thrived,
# Nearest to were: are, was, landfill, impure, kraft, have, pressed, stranded,
# Average loss at step 22000: 3.800073
# Average loss at step 24000: 3.742299
# Average loss at step 26000: 3.737261
# Average loss at step 28000: 3.782590
# Average loss at step 30000: 3.777390
# Nearest to new: signature, beauchamp, publishing, thx, borrow, strewn, limburgish, cracked,
# Nearest to seven: six, five, eight, four, nine, zero, three, one,
# Nearest to was: is, were, had, has, be, are, petronas, been,
# Nearest to d: UNK, lai, c, silverberg, cubans, la, hauge, reductase,
# Nearest to states: nations, psychoanalyst, fingerings, tasso, reap, redneck, interactivity, yuan,
# Nearest to by: bram, who, merwara, alpine, leases, lucie, mahagonny, crusading,
# Nearest to at: after, on, during, males, when, meaningfully, expellees, comments,
# Nearest to an: a, the, this, their, shores, orator, humps, overloaded,
# Nearest to than: or, nationalists, wrong, cubic, hmso, upbeat, like, mugwort,
# Nearest to is: was, are, has, catch, hydrogens, ejective, belongs, horribly,
# Nearest to would: will, may, can, could, did, should, fluctuate, radioisotope,
# Nearest to this: which, it, the, not, that, its, never, an,
# Nearest to war: ghost, padawan, aml, jared, america, fowl, aide, nada,
# Nearest to may: can, would, could, will, volleyball, encyclopedias, must, should,
# Nearest to often: also, blenheim, matra, widely, cameroun, frequently, karloff, sharpening,
# Nearest to were: are, was, had, have, being, landfill, their, be,
# Average loss at step 32000: 3.766390
# Average loss at step 34000: 3.778780
# Average loss at step 36000: 3.723778
# Average loss at step 38000: 3.686295
# Average loss at step 40000: 3.737545
# Nearest to new: sixth, publishing, signature, beauchamp, thx, london, aviator, city,
# Nearest to seven: eight, six, five, nine, four, zero, three, one,
# Nearest to was: is, were, had, has, been, became, being, are,
# Nearest to d: e, c, la, silverberg, g, du, equalled, haram,
# Nearest to states: nations, kingdom, psychoanalyst, racehorse, tasso, interactivity, organisation, siam,
# Nearest to by: bram, merwara, crusading, leases, who, under, faunas, through,
# Nearest to at: during, sepsis, kets, brisk, before, bombard, arrays, influences,
# Nearest to an: the, a, this, ernesto, conflated, tarquin, milling, frankfort,
# Nearest to than: or, much, but, more, nationalists, countermeasure, upbeat, wrong,
# Nearest to is: was, are, has, hydrogens, exertion, broz, includes, can,
# Nearest to would: will, may, could, can, to, did, should, might,
# Nearest to this: which, the, it, a, its, that, not, an,
# Nearest to war: ghost, world, hobbit, aml, jared, news, stone, fowl,
# Nearest to may: can, would, will, could, must, should, to, might,
# Nearest to often: also, widely, sometimes, usually, frequently, matra, blenheim, priming,
# Nearest to were: are, was, have, had, been, being, stranded, many,
# Average loss at step 42000: 3.653290
# Average loss at step 44000: 3.656691
# Average loss at step 46000: 3.628944
# Average loss at step 48000: 3.608075
# Average loss at step 50000: 3.725705
# Nearest to new: sixth, thx, beauchamp, york, sponsors, publishing, queueing, town,
# Nearest to seven: six, eight, four, five, nine, three, zero, one,
# Nearest to was: is, were, became, had, has, being, are, be,
# Nearest to d: b, c, antoine, e, vacuoles, gymnasts, pixel, la,
# Nearest to states: nations, kingdom, interactivity, collaborating, netherlands, lap, organisation, judicial,
# Nearest to by: through, melting, before, with, using, bram, from, syndicalism,
# Nearest to at: for, from, during, phallic, titanic, overshadowed, when, expellees,
# Nearest to an: a, ernesto, the, noblemen, westerners, this, complain, constitutionality,
# Nearest to than: or, and, but, more, much, for, nationalists, less,
# Nearest to is: was, are, has, be, samos, revolvers, inherit, became,
# Nearest to would: will, may, could, can, did, should, might, to,
# Nearest to this: which, it, that, any, a, another, what, no,
# Nearest to war: ghost, world, aml, jared, hobbit, incantation, fowl, grids,
# Nearest to may: can, could, would, will, must, should, might, does,
# Nearest to often: sometimes, also, usually, widely, now, frequently, be, still,
# Nearest to were: are, was, had, be, many, have, drilling, engaging,
# Average loss at step 52000: 3.694622
# Average loss at step 54000: 3.534023
# Average loss at step 56000: 3.694042
# Average loss at step 58000: 3.611899
# Average loss at step 60000: 3.654226
# Nearest to new: york, queueing, sixth, sponsors, beauchamp, aviator, thx, zeus,
# Nearest to seven: six, eight, five, three, four, nine, one, two,
# Nearest to was: is, were, being, be, became, been, had, has,
# Nearest to d: b, antoine, la, heflin, comedian, walter, haram, norah,
# Nearest to states: kingdom, nations, netherlands, state, collaborating, fingerings, hanse, interactivity,
# Nearest to by: bram, mahagonny, before, into, ministership, under, cora, through,
# Nearest to at: when, kouchner, before, on, during, excessively, carnival, sideband,
# Nearest to an: another, nevis, complain, orator, peugeot, conflated, milling, abbey,
# Nearest to than: or, much, even, more, palamas, journeyman, islamabad, dissonant,
# Nearest to is: was, has, are, be, arrangement, broz, being, means,
# Nearest to would: will, could, may, did, can, does, should, might,
# Nearest to this: which, it, that, what, another, navigating, vg, a,
# Nearest to war: ghost, incantation, hobbit, legation, rabies, salah, world, istanbul,
# Nearest to may: can, could, will, would, should, must, might, does,
# Nearest to often: sometimes, usually, also, widely, now, frequently, generally, which,
# Nearest to were: are, was, drilling, stranded, prefer, being, many, eminent,
# Average loss at step 62000: 3.609851
# Average loss at step 64000: 3.492081
# Average loss at step 66000: 3.701630
# Average loss at step 68000: 3.709182
# Average loss at step 70000: 3.706184
# Nearest to new: york, sixth, thx, aviator, sponsors, queueing, disillusionment, beauchamp,
# Nearest to seven: six, eight, five, four, nine, three, zero, two,
# Nearest to was: is, were, has, had, are, been, became, being,
# Nearest to d: b, c, then, porpoise, r, whitish, lieberman, x,
# Nearest to states: nations, kingdom, united, interactivity, racehorse, netherlands, foods, airliners,
# Nearest to by: bram, from, when, into, with, eclac, disparage, stalling,
# Nearest to at: during, arrays, in, while, from, lj, bombard, larval,
# Nearest to an: another, a, the, milling, his, humps, athenaeum, disruptive,
# Nearest to than: much, or, far, even, dissonant, before, less, palamas,
# Nearest to is: was, are, has, marathon, be, being, were, became,
# Nearest to would: will, may, could, can, did, might, should, does,
# Nearest to this: it, another, which, that, what, poses, navigating, anteater,
# Nearest to war: incantation, ghost, halfdan, hobbit, istanbul, cues, padawan, world,
# Nearest to may: can, would, could, will, might, should, must, does,
# Nearest to often: sometimes, usually, also, now, widely, commonly, frequently, generally,
# Nearest to were: are, was, been, stranded, drilling, is, being, be,
# Average loss at step 72000: 3.640277
# Average loss at step 74000: 3.669601
# Average loss at step 76000: 3.673799
# Average loss at step 78000: 3.577480
# Average loss at step 80000: 3.384026
# Nearest to new: york, sixth, solanaceae, borrow, persists, aviator, wheat, federally,
# Nearest to seven: five, six, three, four, eight, nine, one, zero,
# Nearest to was: is, were, been, had, being, became, has, be,
# Nearest to d: b, c, corrections, f, levi, postpositions, whitish, lieberman,
# Nearest to states: nations, kingdom, united, foods, union, fingerings, interactivity, airliners,
# Nearest to by: under, bram, has, however, only, merwara, apprehended, sisterhood,
# Nearest to at: expellees, before, during, titanic, refrigerants, thursdays, larval, beverley,
# Nearest to an: another, the, a, this, millie, its, microarchitecture, radiotelephone,
# Nearest to than: broccoli, even, much, dissonant, encyclopedic, ahasuerus, hermaphrodite, more,
# Nearest to is: was, are, has, became, being, were, means, be,
# Nearest to would: will, could, can, may, did, should, might, does,
# Nearest to this: it, which, another, that, a, gulliver, the, what,
# Nearest to war: during, world, incantation, hobbit, istanbul, ghost, undertook, padawan,
# Nearest to may: can, would, could, will, should, must, might, does,
# Nearest to often: usually, sometimes, widely, frequently, now, commonly, generally, typically,
# Nearest to were: are, was, being, be, is, had, been, stranded,
# Average loss at step 82000: 3.735467
# Average loss at step 84000: 3.656941
# Average loss at step 86000: 3.621688
# Average loss at step 88000: 3.686999
# Average loss at step 90000: 3.691505
# Nearest to new: york, aviator, different, publishing, sixth, nike, wheat, scat,
# Nearest to seven: six, five, eight, four, three, nine, zero, one,
# Nearest to was: is, became, were, had, has, fearful, being, been,
# Nearest to d: b, c, levi, la, heinrich, f, corrections, silverberg,
# Nearest to states: kingdom, nations, foods, united, racehorse, interactivity, airliners, collaborating,
# Nearest to by: bram, through, when, with, connacht, uomo, before, crusading,
# Nearest to at: text, in, larval, from, phallic, during, dervish, before,
# Nearest to an: another, constitutionality, millie, a, milling, any, noblemen, geese,
# Nearest to than: even, much, or, recent, broccoli, countermeasure, typographical, dissonant,
# Nearest to is: was, are, became, means, has, be, being, revolvers,
# Nearest to would: will, could, may, can, did, should, might, does,
# Nearest to this: it, which, another, that, poses, particular, any, backplane,
# Nearest to war: istanbul, hobbit, undertook, during, incantation, cues, allison, ghost,
# Nearest to may: can, could, will, should, would, must, might, does,
# Nearest to often: sometimes, usually, widely, typically, commonly, generally, also, frequently,
# Nearest to were: are, was, including, had, been, those, stranded, bruin,
# Average loss at step 92000: 3.684963
# Average loss at step 94000: 3.679785
# Average loss at step 96000: 3.666605
# Average loss at step 98000: 3.680358
# Average loss at step 100000: 3.647576
# Nearest to new: york, smuggle, began, aviator, sixth, beauchamp, zeus, thx,
# Nearest to seven: six, eight, nine, four, five, three, zero, one,
# Nearest to was: is, became, were, had, been, being, himself, be,
# Nearest to d: b, c, la, corrections, heinrich, levi, lieberman, residing,
# Nearest to states: kingdom, nations, united, foods, airliners, collaborating, racehorse, drexler,
# Nearest to by: bram, using, claudius, cora, noticed, bayreuth, ferroelectric, thurman,
# Nearest to at: phallic, until, tabby, apartments, yeti, near, boudica, bruges,
# Nearest to an: another, copyrighted, nevis, millie, the, ernesto, milling, kidding,
# Nearest to than: or, much, even, while, recent, typographical, aconcagua, eclecticism,
# Nearest to is: was, are, became, has, includes, means, becomes, were,
# Nearest to would: will, could, can, did, should, might, may, must,
# Nearest to this: it, what, that, which, another, poses, the, only,
# Nearest to war: cues, undertook, netted, incantation, jared, landfall, transfection, hobbit,
# Nearest to may: can, could, will, must, would, should, might, does,
# Nearest to often: sometimes, usually, widely, generally, frequently, commonly, typically, also,
# Nearest to were: are, was, had, have, those, been, be, many,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15,15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                       ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1 # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size // num_skips):
        target = skip_window  # target label at the center of the buffer
        targets_to_avoid = [ skip_window ]
        for j in range(num_skips):
            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
            targets_to_avoid.append(target)
            # here different from skip-gram model we switch batch and labels
            batch[i * num_skips + j] = buffer[target]
            labels[i * num_skips + j, 0] = buffer[skip_window]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['as', 'anarchism', 'originated', 'a', 'as', 'term', 'of', 'a']
#     labels: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['a', 'anarchism', 'term', 'originated', 'originated', 'as', 'of', 'term']
#     labels: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 2 # How many words to consider left and right.
num_skips = 4 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
    # Variables.
    embeddings = tf.Variable(
                    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(
                    tf.truncated_normal([vocabulary_size, embedding_size],
                                         stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
    # Model.
    # Look up embeddings for inputs.
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(
        tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` method will by default modify all variable quantities 
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)

    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(
                            normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(
                                  batch_size, num_skips, skip_window)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 20000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.528022
# Nearest to th: safer, nairobi, duckworth, halted, trilobites, northeasterly, lavrenty, dewitt,
# Nearest to who: sk, catholic, campaigning, ernest, piazza, lucien, encodes, epics,
# Nearest to d: guessed, symmetries, dont, reducible, luckily, ministerio, ville, cabbie,
# Nearest to six: mckernan, incomes, jeeps, elwood, mischief, protease, langevin, seamus,
# Nearest to see: kissing, superb, hanseatic, secedes, collects, bartolommeo, bruford, met,
# Nearest to all: megabits, taping, divisibility, corinthian, prague, linnean, introduce, gerard,
# Nearest to also: gogh, naomi, gerald, niigata, batcave, shunning, instinctively, vesuvius,
# Nearest to can: loss, tinbergen, better, bhra, fis, haredi, explode, oss,
# Nearest to about: boxers, gin, corwin, cigarette, kanal, martina, potato, gourmet,
# Nearest to after: asymptotic, mieszko, laid, kriegsmarine, altitudes, aeschylus, mattel, carrot,
# Nearest to would: humayun, bangkok, byrd, sc, firewood, enid, valentinians, zanetti,
# Nearest to war: donors, race, fuelling, zoroastrian, colleen, thousand, divisibility, bravely,
# Nearest to more: horrific, ceti, paramilitary, vocabulary, iridium, pantheon, follow, multipurpose,
# Nearest to their: scotia, hype, nen, canaanites, sarris, perp, specifically, universal,
# Nearest to in: brush, till, peritoneum, linemen, trampoline, liberally, risen, hydroxides,
# Nearest to american: sy, infamy, spike, discounted, weaning, gleichschaltung, oecd, polishing,
# Average loss at step 2000: 4.536225
# Average loss at step 4000: 4.039574
# Average loss at step 6000: 4.023638
# Average loss at step 8000: 3.822068
# Average loss at step 10000: 3.862594
# Average loss at step 12000: 3.766275
# Average loss at step 14000: 3.766365
# Average loss at step 16000: 3.845100
# Average loss at step 18000: 3.809072
# Average loss at step 20000: 3.663047
# Nearest to th: duckworth, nairobi, halted, uploads, trilobites, cooh, cycladic, safer,
# Nearest to who: he, stockton, sk, functional, convection, howlin, weaken, health,
# Nearest to d: b, navel, californians, lumley, j, evacuate, ville, disrespect,
# Nearest to six: five, seven, eight, four, nine, three, zero, two,
# Nearest to see: mythographers, tattooing, christmas, hubris, recognizable, parsers, slava, collects,
# Nearest to all: economic, jen, over, voices, some, lull, megabits, rue,
# Nearest to also: reptiles, twofold, extremely, hain, servicemen, delaying, chevron, invading,
# Nearest to can: may, will, could, would, must, cannot, nina, is,
# Nearest to about: relying, leu, peake, potato, executed, rethinking, fahrenheit, martina,
# Nearest to after: har, kriegsmarine, bandanese, during, cotswolds, since, invulnerable, for,
# Nearest to would: will, cannot, can, may, to, firewood, adhemar, had,
# Nearest to war: colleen, race, freemasons, kliper, fjord, observances, edvac, juveniles,
# Nearest to more: less, slaves, provably, funniest, rss, sica, longer, arabs,
# Nearest to their: his, its, the, a, some, any, seized, wigs,
# Nearest to in: from, on, at, during, of, lcc, motherhood, obscured,
# Nearest to american: spike, pravda, british, sever, tsar, kemp, prophase, kvass,
# Average loss at step 22000: 3.784808
# Average loss at step 24000: 3.684015
# Average loss at step 26000: 3.734588
# Average loss at step 28000: 3.630713
# Average loss at step 30000: 3.632776
# Average loss at step 32000: 3.764626
# Average loss at step 34000: 3.777251
# Average loss at step 36000: 3.779579
# Average loss at step 38000: 3.693344
# Average loss at step 40000: 3.731649
# Nearest to th: nine, km, zero, albums, eight, cycladic, nairobi, odour,
# Nearest to who: he, they, stockton, you, sofa, danes, exercise, encompasses,
# Nearest to d: b, p, t, j, convict, epistemology, m, lumley,
# Nearest to six: seven, eight, three, five, four, nine, zero, two,
# Nearest to see: list, links, emblem, ib, downfall, destinations, kosovar, pantheistic,
# Nearest to all: some, other, these, many, several, their, are, economic,
# Nearest to also: rooftop, preaching, which, nyc, still, never, skinned, nevertheless,
# Nearest to can: may, could, will, would, should, must, cannot, xiith,
# Nearest to about: leu, lucca, before, pickled, dobbs, over, riot, five,
# Nearest to after: during, before, for, since, when, with, while, following,
# Nearest to would: will, may, can, could, cannot, should, might, must,
# Nearest to war: observances, second, colleen, casinos, goblin, eth, sheikh, world,
# Nearest to more: less, rather, funniest, abort, sq, provably, very, vagina,
# Nearest to their: its, his, both, these, other, the, any, all,
# Nearest to in: and, since, of, at, courtois, obscured, irene, discernment,
# Nearest to american: spike, british, partaking, firefighters, galahad, hampering, including, french,
# Average loss at step 42000: 3.739398
# Average loss at step 44000: 3.631238
# Average loss at step 46000: 3.456343
# Average loss at step 48000: 3.774653
# Average loss at step 50000: 3.709933
# Average loss at step 52000: 3.666782
# Average loss at step 54000: 3.727832
# Average loss at step 56000: 3.726928
# Average loss at step 58000: 3.730813
# Average loss at step 60000: 3.719082
# Nearest to th: nd, nine, zero, km, eight, six, cycladic, nairobi,
# Nearest to who: he, have, sofa, they, she, elliott, stockton, reachable,
# Nearest to d: b, j, salutation, p, t, moore, gabriel, epistemology,
# Nearest to six: seven, eight, five, four, three, zero, nine, one,
# Nearest to see: list, links, eddy, emblem, hanseatic, renouf, kosovar, ib,
# Nearest to all: many, some, various, both, several, any, other, incoming,
# Nearest to also: often, now, still, amadeus, toolbox, that, usually, sometimes,
# Nearest to can: may, could, will, must, would, should, cannot, might,
# Nearest to about: leu, over, after, llu, before, bluffs, fgth, democrat,
# Nearest to after: during, before, following, when, of, over, about, disenfranchised,
# Nearest to would: will, could, may, can, should, must, cannot, did,
# Nearest to war: husky, colleen, second, vocation, lyr, world, casinos, observances,
# Nearest to more: less, rather, very, most, looked, much, about, spearhead,
# Nearest to their: its, his, the, both, other, her, many, euston,
# Nearest to in: from, since, during, on, through, until, discernment, of,
# Nearest to american: german, british, spike, english, film, team, french, italian,
# Average loss at step 62000: 3.702442
# Average loss at step 64000: 3.708135
# Average loss at step 66000: 3.680631
# Average loss at step 68000: 3.684662
# Average loss at step 70000: 3.622855
# Average loss at step 72000: 3.559247
# Average loss at step 74000: 3.673577
# Average loss at step 76000: 3.690882
# Average loss at step 78000: 3.711494
# Average loss at step 80000: 3.619215
# Nearest to th: nd, nine, st, seven, eight, four, six, hardcover,
# Nearest to who: he, decimus, tejada, stockton, nox, she, camelcase, ti,
# Nearest to d: b, j, c, moore, r, pellets, californians, salutation,
# Nearest to six: seven, four, eight, five, three, nine, zero, two,
# Nearest to see: links, list, emblem, kosovar, eddy, rosette, external, wil,
# Nearest to all: many, some, various, any, several, both, these, none,
# Nearest to also: now, which, intruder, rooftop, elisa, ill, josaphat, moira,
# Nearest to can: could, may, will, must, would, should, might, cannot,
# Nearest to about: over, six, main, lifeson, bothwell, less, techstep, hardcover,
# Nearest to after: before, during, when, following, multiprogramming, pus, camilla, sovereign,
# Nearest to would: will, could, can, may, might, must, should, did,
# Nearest to war: during, wars, fought, prospects, eth, posner, colleen, aq,
# Nearest to more: less, very, rather, most, looked, vagina, spearhead, provably,
# Nearest to their: its, her, his, both, any, other, the, these,
# Nearest to in: on, since, zoology, during, lackluster, feb, kama, and,
# Nearest to american: british, film, science, african, national, heritage, canadian, spike,
# Average loss at step 82000: 3.672940
# Average loss at step 84000: 3.559540
# Average loss at step 86000: 3.662435
# Average loss at step 88000: 3.647365
# Average loss at step 90000: 3.700257
# Average loss at step 92000: 3.643123
# Average loss at step 94000: 3.645246
# Average loss at step 96000: 3.703218
# Average loss at step 98000: 3.666442
# Average loss at step 100000: 3.668112
# Nearest to th: eight, nine, seven, nd, four, six, zero, st,
# Nearest to who: decimus, he, she, gonzalez, they, banish, living, sofa,
# Nearest to d: b, n, c, salutation, g, m, t, f,
# Nearest to six: seven, eight, five, four, nine, three, zero, one,
# Nearest to see: article, links, list, headlands, references, destinations, kosovar, but,
# Nearest to all: many, some, several, both, various, any, these, most,
# Nearest to also: now, which, often, sometimes, what, that, because, below,
# Nearest to can: may, will, could, must, should, might, would, cannot,
# Nearest to about: dobbs, despised, makes, fanning, main, over, confining, techstep,
# Nearest to after: before, during, following, when, pus, frightened, for, sees,
# Nearest to would: will, could, may, should, must, might, can, did,
# Nearest to war: during, wars, chiropractors, mountaineer, eth, observances, posner, donnell,
# Nearest to more: less, very, rather, most, highly, quite, longer, extremely,
# Nearest to their: its, his, her, the, both, our, any, many,
# Nearest to in: during, gadol, since, until, within, from, laguna, alfons,
# Nearest to american: british, film, international, singers, canadian, english, bookshelf, association,
